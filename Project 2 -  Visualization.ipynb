# %%
import pandas as pd

# %%
df = pd.read_csv("./Resources/Electric_Vehicle_Charging_Stations.csv")
df
# Out:
#                                          Location Name  \
# 0                           Connecticut Science Center
# 1                            Norwalk Community College
# 2                               Milford Public Library
# 3                                    Lombard Ford Inc.
# 4                                     Manchester Honda
# 5                                        INFINITYGREEN
# 6    Propark America - Omni Hotel Chapel Square Garage
# 7                                       Town of Bethel
# 8      Air Rights Garage (New Haven Parking Authority)
# 9                         Greensfarms Railroad Station
# 10                            Morton Government Center
# 11                   Rt 15- NB Greenwich Service Plaza
# 12                                              Big Y
# 13                                Plainville Town Hall
# 14                                  The Dock-Rail Side
# 15                                   Curran Volkswagon
# ...

# %%
list(df["Location 1"])
# Out:
# ['250 Columbus Blvd\nHartford\n(41.764599, -72.669526)',
#  '188 Richards Avenue\nNorwalk\n(41.102614, -73.450294)',
#  '57 New Haven Avenue\nMilford\n(41.2225623, -73.0546839)',
#  '385 New Hartford Road\nBarkhamsted\n(41.909669, -73.042491)',
#  '24 Adams Street\nManchester\n(41.795808, -72.55138)',
#  '201 Commons Park Street\nStamford\n(41.0410423, -73.5396723)',
#  '155 Temple Street\nNew Haven\n(41.3058626, -72.9275359)',
#  '5 Depot Place\nBethel\n(41.370439, -73.414611)',
#  '60 York Street (Located on level 3 of garage)\nNew Haven\n(41.305202, -72.934014)',
#  '2 Post Office Lane\nWestport\n(41.122741, -73.315848)',
#  '239 John Street\nBridgeport\n(41.177081, -73.191365)',
#  '3000 Merritt Parkway\nGreenwich\n(41.041098, -73.672417)',
#  '28 Spencer Plain Road\nOld Saybrook\n(41.28808, -72.417843)',
#  '1 Central Square\nPlainville\n(41.6717114, -72.8670213)',
#  '200 East Main Street\nStamford\n(41.20277023, -73.11752319)',
# ...

# %%
df.shape
# Out:
# (215, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 9 columns):
# Location Name       215 non-null object
# Street Address      215 non-null object
# Hours Open          215 non-null object
# Level               215 non-null object
# Location 1          215 non-null object
# Planning Regions    214 non-null float64
# Counties            215 non-null int64
# Zip Code            215 non-null int64
# Town Index          214 non-null float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 15.2+ KB

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 214 entries, 0 to 214
# Data columns (total 9 columns):
# Location Name       214 non-null object
# Street Address      214 non-null object
# Hours Open          214 non-null object
# Level               214 non-null object
# Location 1          214 non-null object
# Planning Regions    214 non-null float64
# Counties            214 non-null int64
# Zip Code            214 non-null int64
# Town Index          214 non-null float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 16.7+ KB

# %%
mylist = [i.split("\n") for i in df["Location 1"]]
mylist
# Out:
# [['250 Columbus Blvd', 'Hartford', '(41.764599, -72.669526)'],
#  ['188 Richards Avenue', 'Norwalk', '(41.102614, -73.450294)'],
#  ['57 New Haven Avenue', 'Milford', '(41.2225623, -73.0546839)'],
#  ['385 New Hartford Road', 'Barkhamsted', '(41.909669, -73.042491)'],
#  ['24 Adams Street', 'Manchester', '(41.795808, -72.55138)'],
#  ['201 Commons Park Street', 'Stamford', '(41.0410423, -73.5396723)'],
#  ['155 Temple Street', 'New Haven', '(41.3058626, -72.9275359)'],
#  ['5 Depot Place', 'Bethel', '(41.370439, -73.414611)'],
#  ['60 York Street (Located on level 3 of garage)',
#   'New Haven',
#   '(41.305202, -72.934014)'],
#  ['2 Post Office Lane', 'Westport', '(41.122741, -73.315848)'],
#  ['239 John Street', 'Bridgeport', '(41.177081, -73.191365)'],
#  ['3000 Merritt Parkway', 'Greenwich', '(41.041098, -73.672417)'],
#  ['28 Spencer Plain Road', 'Old Saybrook', '(41.28808, -72.417843)'],
#  ['1 Central Square', 'Plainville', '(41.6717114, -72.8670213)'],
# ...

# %%
Coordinates = []

for i in mylist:
    Coordinates.append(i[2])
print(Coordinates)
# Out:
# ['(41.764599, -72.669526)', '(41.102614, -73.450294)', '(41.2225623, -73.0546839)', '(41.909669, -73.042491)', '(41.795808, -72.55138)', '(41.0410423, -73.5396723)', '(41.3058626, -72.9275359)', '(41.370439, -73.414611)', '(41.305202, -72.934014)', '(41.122741, -73.315848)', '(41.177081, -73.191365)', '(41.041098, -73.672417)', '(41.28808, -72.417843)', '(41.6717114, -72.8670213)', '(41.20277023, -73.11752319)', '(41.198467, -73.131808)', '(41.9979545, -72.5742057)', '(41.389547, -73.467467)', '(41.2777553, -72.8716481)', '(41.399095, -73.44344)', '(41.711942, -72.608505)', '(41.771441, -72.967039)', '(41.800922, -72.241321)', '(41.666233, -72.781161)', '(41.5785572, -73.41116)', '(41.783595, -72.748049)', '(41.914329, -71.9105762)', '(41.491597, -72.091456)', '(41.378259, -73.474835)', '(41.187855, -73.250024)', '(41.53697, -72.805988)', '(41.6659341, -72.8580302)', '(41.043283, -73.573851)', '(41.745582, -72.689438)', '(41.080085, -73.461261)', '(41.983904, -72.489406)', '(41.05402
# ...

# %%
df['Coordinates'] = Coordinates
# Out:
# C:\Users\tdgso\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                                          Location Name  \
# 0                           Connecticut Science Center
# 1                            Norwalk Community College
# 2                               Milford Public Library
# 3                                    Lombard Ford Inc.
# 4                                     Manchester Honda
# 5                                        INFINITYGREEN
# 6    Propark America - Omni Hotel Chapel Square Garage
# 7                                       Town of Bethel
# 8      Air Rights Garage (New Haven Parking Authority)
# 9                         Greensfarms Railroad Station
# 10                            Morton Government Center
# 11                   Rt 15- NB Greenwich Service Plaza
# 12                                              Big Y
# 13                                Plainville Town Hall
# 14                                  The Dock-Rail Side
# 15                                   Curran Volkswagon
# ...

# %%
df.to_csv('Charging_Stations_Clean.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 214 entries, 0 to 214
# Data columns (total 10 columns):
# Location Name       214 non-null object
# Street Address      214 non-null object
# Hours Open          214 non-null object
# Level               214 non-null object
# Location 1          214 non-null object
# Planning Regions    214 non-null float64
# Counties            214 non-null int64
# Zip Code            214 non-null int64
# Town Index          214 non-null float64
# Coordinates         214 non-null object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 18.4+ KB

# %%
df = df.drop(columns="Location 1")
df
# Out:
#                                          Location Name  \
# 0                           Connecticut Science Center
# 1                            Norwalk Community College
# 2                               Milford Public Library
# 3                                    Lombard Ford Inc.
# 4                                     Manchester Honda
# 5                                        INFINITYGREEN
# 6    Propark America - Omni Hotel Chapel Square Garage
# 7                                       Town of Bethel
# 8      Air Rights Garage (New Haven Parking Authority)
# 9                         Greensfarms Railroad Station
# 10                            Morton Government Center
# 11                   Rt 15- NB Greenwich Service Plaza
# 12                                              Big Y
# 13                                Plainville Town Hall
# 14                                  The Dock-Rail Side
# 15                                   Curran Volkswagon
# ...

# %%
df.to_csv('Charging_Stations_Clean_2.csv')

# %%
df.columns = ['Location_Name', 'Street_Address', 'Hours_Open', 'Level', 'Planning_Regions', 'Counties', 'Zip_Code', 'Town_Index'	Coordinates]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-9416a8b6ef71> in <module>
#       1 df.columns({
# ----> 2     "Location Name": "Location_Name"
#       3 })
#
# TypeError: 'Index' object is not callable
